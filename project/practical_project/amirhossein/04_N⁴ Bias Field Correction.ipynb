# %%
import os
import SimpleITK as sitk

# Define input and output directories
nifti_input_dir = "NIfTI_Reoriented"  # Input: Reoriented images
nifti_output_dir = "NIfTI_BiasCorrected"  # Output: Bias-corrected images

# Ensure output directory exists
os.makedirs(nifti_output_dir, exist_ok=True)

# Function to apply N4 bias field correction with type conversion
def n4_bias_correction(input_nifti_path, output_nifti_path):
    try:
        # Load image
        image = sitk.ReadImage(input_nifti_path)

        # Convert image to Float32 to avoid integer type errors
        image = sitk.Cast(image, sitk.sitkFloat32)

        # Generate a binary mask using Otsu thresholding
        mask_image = sitk.OtsuThreshold(image, 0, 1, 200)

        # Apply N4 Bias Field Correction
        corrected_image = sitk.N4BiasFieldCorrection(image, mask_image)

        # Save corrected image
        sitk.WriteImage(corrected_image, output_nifti_path)
        print(f"Bias corrected: {output_nifti_path}")

    except Exception as e:
        print(f"Failed to correct {input_nifti_path}: {e}")

# Loop through all NIfTI files and apply bias correction
for filename in os.listdir(nifti_input_dir):
    if filename.endswith(".nii.gz") and "Tumor_segmentation" not in filename:  # Avoid segmentation masks
        input_nifti_path = os.path.join(nifti_input_dir, filename)
        output_nifti_path = os.path.join(nifti_output_dir, filename)
        n4_bias_correction(input_nifti_path, output_nifti_path)

print(f"Bias field correction complete. Files saved in: {nifti_output_dir}")
# Out:
# Bias corrected: NIfTI_BiasCorrected\LGG-104_Gad_Ax_SPGR_Straight.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-104_Gad_Ax_T2_Straight.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-203_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-203_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-210_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-210_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-216_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-216_Ax_Obl_FSE_gad.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-218_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-218_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-219_axial_T1GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-219_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-220_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-220_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-223_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-223_Ax_Obl_FSE_gad.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-225_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-225_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-229_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-229_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-231_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-231_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-233_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-233_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-234_Gad_Ax_BRAVO_ARC.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-234_Gad_Ax_T2_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-240_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-240_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-241_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-241_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-246_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-246_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-249_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-249_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-254_Post_Gd_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-254_Post_Gd_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-260_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-260_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-261_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-261_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-263_Post_Gd_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-263_Post_Gd_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-269_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-269_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-273_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-273_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-274_AX_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-274_AX_T1_GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-277_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-277_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-278_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-278_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-280_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-280_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-282_Post_Gd_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-282_Post_Gd_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-285_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-285_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-286_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-286_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-288_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-288_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-289_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-289_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-293_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-293_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-295_t1fl3dtraGREGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-295_t2fseAXGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-296_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-296_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-297_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-297_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-298_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-298_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-303_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-303_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-304_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-304_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-305_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-305_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-306_Ax_3D_TOF_SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-306_Ax_T2_FSE_POST_GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-307_Post_Gad_AX._SPGR.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-307_Post_Gad_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-308_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-308_head_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-310_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-310_ax_K2.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-311_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-311_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-313_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-313_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-314_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-314_Ax_Obl_FSEgad.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-315_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-315_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-316_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-316_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-320_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-320_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-321_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-321_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-325_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-325_AX_T2_OBL.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-326_axial_T1__GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-326_Ax_Obl_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-327_AX_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-327_AX_T1_GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-330_AX_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-330_AX_T1_GAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-331_AX._SPGRGAD.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-331_axial_FSE.nii.gz
# Bias corrected: NIfTI_BiasCorrected\LGG-333_AX._SPGRGAD.nii.gz
